# %% [markdown]
# ## Ticketmaster Test
# Goal: Test ticketmaster API and learn how it works

# %%
import requests
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access the API key
ticketmaster_key = os.getenv("TICKETMASTER_API_KEY")

# %%
def makeTicketmasterEventRequest(package, version, eventparams):
    # Format for looking at events: https://app.ticketmaster.com/{package}/{version}/events.json?{eventparams}apikey={API key}
    # eventparams needs to be separated by & symbols for each query. Check ticketmaster discovery page to see all query options

    url = f'https://app.ticketmaster.com/{package}/{version}/events.json?{eventparams}apikey={ticketmaster_key}'

    r = requests.get(url)

    return r

# %%
# def makeTicketmasterEventDetailsRequest(id: str):
#     print(f"--- Calling Ticketmaster API with id: {id} ---")
#     params['apikey'] = ticketmaster_key
#     url = f'https://app.ticketmaster.com/discovery/v2/events/{id}.json?apikey={ticketmaster_key}'

#     r = requests.get(url)
#     print(f"--- Ticketmaster Details API Status Code: {r.status_code} ---")

#     return r.text

# %%
def makeTicketmasterEventDetailsRequest(params: dict):
    params['apikey'] = ticketmaster_key
    print(f"--- Calling Ticketmaster API with params: {params} ---")
    
    url = f'https://app.ticketmaster.com/discovery/v2/events/{params['id']}.json'

    r = requests.get(url,params=params)
    print(f"--- Ticketmaster Details API Status Code: {r.status_code} ---")

    return r.text

# %%
def makeSearchSuggestion(params: dict):
    print(f"--- Calling Ticketmaster Search Suggestions API with params: {params} ---")
    params['apikey'] = ticketmaster_key
    url = f'https://app.ticketmaster.com/discovery/v2/suggest'
    
    r = requests.get(url, params=params)
    print(f"--- Ticketmaster Search Suggestions API Status Code: {r.status_code} ---")
    return

# %%
# Be sure to include an '&' at the end of your parameters for your query for your event for the request to pass through
r = makeTicketmasterEventRequest(package='discovery', version='v2', eventparams='stateCode=MI&')
r.text['']
# Out:
# '{"_embedded":{"events":[{"name":"Detroit Red Wings vs. Florida Panthers","type":"event","id":"vvG1OZbC1JEeR-","test":false,"url":"https://www.ticketmaster.com/detroit-red-wings-vs-florida-panthers-detroit-michigan-04-06-2025/event/080060E2A69C2BE1","locale":"en-us","images":[{"ratio":"3_2","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_ARTIST_PAGE_3_2.jpg","width":305,"height":203,"fallback":false},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_EVENT_DETAIL_PAGE_16_9.jpg","width":205,"height":115,"fallback":false},{"ratio":"4_3","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_CUSTOM.jpg","width":305,"height":225,"fallback":false},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_RETINA_PORTRAIT_16_9.jpg","width":640,"height":360,"fallback":false},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_RECOMENDATION_16_9.jpg","width":100,"height":56,"fallback":false},{"ratio":"3_2","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_RETINA_PORTRAIT_3_2.jpg","width":640,"height":427,"fallback":false},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/c/61c/37e6dc36-b80c-45a5-9bc5-960c7a98161c_106321_TABLET_LANDSCAPE_LARGE_16_9.jpg","width":2048,"height":1152,"fallback":true},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_RETINA_LANDSCAPE_16_9.jpg","width":1136,"height":639,"fallback":false},{"ratio":"3_2","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_TABLET_LANDSCAPE_3_2.jpg","width":1024,"height":683,"fallback":false},{"ratio":"16_9","url":"https://s1.ticketm.net/dam/a/015/c6fbf2ff-8115-4f25-aeae-c61bed8d2015_1277431_TABLET_LANDSCAPE_16_9.jpg","width":1024,"height":576,"fallback":false}],"sales":{"public":{"startDateTime":"2024-08-12T14:00:00Z","startTBD":false,"startTBA":false,"endDateTime":"2025-04-06T21:30:00Z"}},"dates":{"start":{"localDate":"2025-04-06","localTime":"17:30:00","dateTime":"2025-04-06T21:30:00Z","dateTBD":false,"dateTBA":false,"timeTBA":false,"noSpecificTime":false},"timezone":"America/New_York","status":{"code":"onsale"},"spanMultipleDays":false},"classifications":[{"primary":true,"segment":{"id":"KZFzniwnSyZfZ7v7nE","name":"Sports"},"genre":{"id":"KnvZfZ7vAdI","name":"Hockey"},"subGenre":{"id":"KZazBEonSMnZfZ7vFEE","name":"NHL"},"type":{"id":"KZAyXgnZfZ7v7l1","name":"Group"},"subType":{"id":"KZFzBErXgnZfZ7vA7d","name":"Team"},"family":false}],"promoter":{"id":"690","name":"NHL REGULAR SEASON","description":"NHL REGULAR SEASON / NTL / USA"},"promoters":[{"id":"690","name":"NHL REGULAR SEASON","description":"NHL REGULAR SEASON / NTL / USA"}],"info":"Bags, Purses, Clutches larger than 4\\" x 6\\" x 1.5\\" are prohibited. Diaper Bags and Medical Bags are permitted and should be no larger than 14\\" x 14\\" x 6\\". The venue is CASHLESS. All tickets are MOBILE. Please download the Ticketmaster App to view and manage your tickets. Please plan to arrive early to reduce your wait time to enter the venue.","pleaseNote":"Bags, Purses, Clutches larger than 4\\" x 6\\" x 1.5\\" are prohibited. Diaper Bags and Medical Bags are permitted and should be no larger than 14\\" x 14\\" x 6\\". The venue is CASHLESS. All tickets are MOBILE. Please download the Ticketmaster App to view and manage your tickets. Please plan to arrive early to reduce your wait time to enter the venue.","priceRanges":[{"type":"standard","currency":"USD","min":67.0,"max":422.25}],"products":[{"name":"PARKWHIZ LITTLE CAESARS ARENA","id":"vvG1OZbCCjVsjw","url":"https://www.ticketmaster.com/parkwhiz-little-caesars-arena-detroit-michigan-04-06-2025/event/080060E39CD31732","type":"Upsell","classifications":[{"primary":true,"segment":{"id":"KZFzniwnSyZfZ7v7n1","name":"Miscellaneous"},"genre":{"id":"KnvZfZ7v7ll", ...

# %%
params = {}
params['id'] = 'vvG1OZbC1JEeR-'
d = makeSearchSuggestion(params)
# d =  makeTicketmasterEventDetailsRequest(params)
d
# Out:
# --- Calling Ticketmaster Search Suggestions API with params: {'id': 'vvG1OZbC1JEeR-'} ---
# --- Ticketmaster Search Suggestions API Status Code: 200 ---

# %%
import json
r_json = r.json()
type(r_json)
# Testing to see what keys
print(r_json.keys())

# printing all events happening in michigan according to ticketmaster 
for i in range(len(r_json['_embedded']['events'])):
    print(r_json['_embedded']['events'][i]['name'])
# Out:
# dict_keys(['_embedded', '_links', 'page'])
# Detroit Red Wings vs. Boston Bruins
# Detroit Red Wings vs. Florida Panthers
# Detroit Red Wings vs. Carolina Hurricanes
# Detroit Red Wings vs. Ottawa Senators
# The Spinners
# Detroit Tigers vs. New York Yankees
# Detroit Tigers vs. New York Yankees
# Detroit Tigers vs. New York Yankees
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)
# Hamilton (Touring)

# %% [markdown]
# ### **Key Take-aways:**
#
# So one take-away from testing the ticketmaster API is perhaps making a series of functions that you can pass into the openAI langchain to answer prompts. I assume we shouldn't implement a database system since these API's are updated often I assume.
#
# A rebuttle to this is the idea of creating a database to store the GET requests so that if multiple GET requests of the same thing are queried, instead of spending all those API calls, we can just pull up the result from that GET request, which was stored in the database. This would require a database that has a rule that deletes data that is, lets say, 1 week old
